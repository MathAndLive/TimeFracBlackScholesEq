# %%
from sampling import compute_first_crossing, plot_subordinator

if __name__ == "__main__":
    alpha = 0.9
    dtau = 1e-2
    T = 1.0

    tau, arr, grid = compute_first_crossing(alpha=alpha,
                                            dtau=dtau,
                                            T=T,
                                            return_path=True)

    plot_subordinator(arr=arr,
                      grid=grid,
                      T=T,
                      tau=tau,
                      alpha=alpha)

    s = 0
    N = 10000
    for i in range(N):
        s += compute_first_crossing(alpha=alpha, dtau=dtau, T=T)
    print(s / N)
# Out:
# 1.044978999999999

# %% [markdown]
# ## Результаты
#
# ### alpha = 0.7
#
# 1 min 18 s для генерации 1000 tau dtau = 1e-4 ()
#
# 1 s для генерации 1000 tau, dtau = 1e-2 (mean = 1.117)
#
# 8 s для генерации 1000 tau, dtau = 1e-3 (mean = 1.083)
